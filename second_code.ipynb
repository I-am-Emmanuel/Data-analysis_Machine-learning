# %% [markdown]
# Gather data iris flower data from sklearn library

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris.data
# iris.target
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %% [markdown]
# Test the data value before spliting

# %%
X = iris.data
y = iris.target

feature_names = iris.feature_names
target_names = iris.target_names
target_names
# feature_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# Split the data into testing and training data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %% [markdown]
# Build/Create model to train and test data

# %%
from sklearn.neighbors import KNeighborsClassifier
# from sklearn.tree import DecisionTreeClassifier
knn = KNeighborsClassifier(n_neighbors=3)
# knn = DecisionTreeClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
y_pred
# Out:
# array([0, 1, 1, 1, 2, 1, 0, 1, 2, 0, 2, 0, 1, 1, 2, 1, 2, 1, 2, 0, 0, 2,
#        2, 1, 0, 0, 0, 0, 2, 0])

# %%
from sklearn import metrics
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9666666666666667

# %%
sample = [[4.6, 3.1, 1.5, 0.2], [2,3,5,34], [5.4, 3.9, 1.7, 0.4]]
prediction = knn.predict(sample)
pred_species = [iris.target_names[p] for p in prediction]
print('predictions: ', pred_species)
# Out:
# predictions:  [np.str_('setosa'), np.str_('virginica'), np.str_('setosa')]

# %%
import joblib
joblib.dump(knn, 'mlbrain.joblib')
# Out:
# ['mlbrain.joblib']

# %%
model = joblib.load('mlbrain.joblib')
# model.predict(sample)
prediction = model.predict(sample)
pred_species = [iris.target_names[p] for p in prediction] 
print('predictions: ', pred_species)
# Out:
# predictions:  [np.str_('setosa'), np.str_('virginica'), np.str_('setosa')]

# %%
def fibonaci(n):
    if n in (0, 1):
        return n
    return fibonaci(n - 1) + fibonaci(n-2)

for i in range(7):
    print(f'Fibonacci {i} = {fibonaci(i)}')
# Out:
# Fibonacci 0 = 0
# Fibonacci 1 = 1
# Fibonacci 2 = 1
# Fibonacci 3 = 2
# Fibonacci 4 = 3
# Fibonacci 5 = 5
# Fibonacci 6 = 8

# %% [markdown]
# F(n)=
# 5
# ϕ n
#  −(−ϕ)
# −n

# %% [markdown]
# Constant Time Complexity: 𝑂(1)

# %%
import math

def fibonacci_formula(n):
    phi = (1 + math.sqrt(5)) / 2
    return round((phi**n - (-phi)**-n) / math.sqrt(5))

print(fibonacci_formula(n=6))
for i in range(9):
    print(f'Fibonacci {i} = {fibonacci_formula(i)}')
# Out:
# 8
# Fibonacci 0 = 0
# Fibonacci 1 = 1
# Fibonacci 2 = 1
# Fibonacci 3 = 2
# Fibonacci 4 = 3
# Fibonacci 5 = 5
# Fibonacci 6 = 8
# Fibonacci 7 = 13
# Fibonacci 8 = 21
